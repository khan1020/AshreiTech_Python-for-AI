# %% [markdown]
# # Python for AI — Class 5
# ### Dictionaries, sets, and your first Skill Checkpoint
#
# Yesterday you stored things **in order**, and looked them up **by position**.
#
# Today you look things up **by name** — which is how almost all real data actually works.
#
# **Hour 3 is your first Weekly Skill Checkpoint.**
#
# **How to use this notebook:** run each cell with the play button, or `Shift + Enter`.
#
# Cells marked **BREAKS ON PURPOSE** are *supposed* to show a red error. Cells marked **WRONG ON PURPOSE** run fine and give the *wrong answer* — those are the dangerous ones. Don't fix either before class; that is the lesson.

# %% [markdown]
# ---
# # 1. The problem dictionaries solve
#
# Store one student's details in a list:

# %%
student = ["Ali", 25, 85, "Karachi"]

print(student[2])

# %% [markdown]
# What is `student[2]`? You have to **remember** that position 2 means marks. In three weeks you won't. And if someone inserts a phone number at position 1, every number in your program is now wrong.
#
# **A dictionary lets you look things up by name.**

# %%
student = {
    "name": "Ali",
    "age": 25,
    "marks": 85,
    "city": "Karachi"
}

print(student["marks"])
print(type(student))
# Out:
# 85
# <class 'dict'>

# %% [markdown]
# Curly braces `{ }`, and each entry is a **key** and a **value**, joined by a colon.
#
# `student["marks"]` says what it means. `student[2]` never did.
#
# > **Think of a dictionary as your phone contacts.** You don't look up "contact number 47." You look up "Ali."

# %% [markdown]
# ---
# # 2. Keys and values

# %%
student = {"name": "Ali", "age": 25, "marks": 85}

print(student["name"])
print(student["age"])
# Out:
# Ali
# 25

# %%
# BREAKS ON PURPOSE - asking for a key that isn't there
student = {"name": "Ali", "age": 25}
print(student["phone"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 3
#       1 # BREAKS ON PURPOSE - asking for a key that isn't there
#       2 student = {"name": "Ali", "age": 25}
# ----> 3 print(student["phone"])
#
# KeyError: 'phone'

# %% [markdown]
# **KeyError** — that key does not exist. This is the dictionary version of yesterday's IndexError.

# %% [markdown]
# ### `.get()` — asking safely

# %%
student = {"name": "Ali", "age": 25}

print(student.get("phone", "+92 300 0000"))  

phone_number = student.get("phone", "-")    # your own fallback
                  # None instead of crashing
# print(student.get("phone", "not provided"))    # your own fallback
# print(student.get("name", "not provided"))

print(phone_number)    # your own fallback
# Out:
# +92 300 0000
# None

# %% [markdown]
# > **Use `.get()` whenever you are not certain the key is there** — which is most of the time when the data came from a file, an API, or a user. Your Month 2 AI work will be full of this.

# %% [markdown]
# ### What can be a key?
#
# Keys must be **immutable**. Text, numbers and tuples work. Lists do not — and now yesterday's mutability lesson pays off.

# %%
# BREAKS ON PURPOSE - a list cannot be a dictionary key
# d = {["a", "b"]: "value"}

d = {1: "value"}

# %%
# A tuple can, because it cannot change
locations = {
    (24.86, 67.01): "Karachi",
    (31.55, 74.34): "Lahore"
}
print(locations[(24.86, 67.01)])
# Out:
# Karachi

# %% [markdown]
# ---
# # 3. Changing a dictionary
#
# Dictionaries are **mutable**, like lists.

# %%
student = {"name": "Ali"}

student["marks"] = 85          # key doesn't exist -> it is ADDED
print(student)

# student["age"] = 26            # key exists -> it is UPDATED
# print(student)

if "age" in student:
    student["age"] = 26        # key exists -> it is UPDATED
# del student["age"]             # remove it
print(student)

removed = student.pop("marks") # remove and hand it back
print(removed, "->", student)
# Out:
# {'name': 'Ali', 'marks': 85}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 9
#       4 print(student)
#       6 # student["age"] = 26            # key exists -> it is UPDATED
#       7 # print(student)
# ----> 9 if student and student["age"] != None:
#      10     del student["age"]             # remove it
#      11 print(student)
#
# KeyError: 'age'

# %% [markdown]
# > **Note the one square bracket does two jobs:** adding and updating look identical. That is convenient, and it also means a typo in a key name silently creates a new entry instead of erroring.

# %%
student = {"name": "Ali", "marks": 85}

age: int = 6

student["marsk"] = 90          # typo!  No error at all.

print(student)                 # now you have both 'marks' and 'marsk'
# Out:
# {'name': 'Ali', 'marks': 85, 'marsk': 90}

# %% [markdown]
# ---
# # 4. Looping over a dictionary
#
# Three ways, and the third is the one you'll use most.

# %%
student = {"name": "Ali", "age": 25, "marks": 85}

print(student.items())

for key, value in student.items():            # looping gives you the KEYS
    # print(key, value)
    pass
    print(student[key])
# Out:
# dict_items([('name', 'Ali'), ('age', 25), ('marks', 85)])
# Ali
# 25
# 85

# %%
for key in student.keys():
    print(key)

print("---")

for value in student.values():
    print(value)
# Out:
# name
# age
# marks
# ---
# Ali
# 25
# 85

# %%
for key, value in student.items():      # BOTH at once - a tuple, unpacked
    print(key, "->", value)
# Out:
# name -> Ali
# age -> 25
# marks -> 85

# %% [markdown]
# `.items()` gives you a tuple per entry, and you unpack it exactly like yesterday's `for name, mark in students`.
#
# **This is the pattern you will use most often.** Get comfortable with it today.

# %% [markdown]
# ---
# # 5. Nesting — real data is shaped like this

# %%
students = {
    "ali": {"age": 25, "marks": None, "city": "Karachi"},
    "fatima": {"age": 23, "marks": 92, "city": "Lahore"}
}

if "marks" not in students:
    students["ali"]["marks"] = 0

print(students["ali"]["marks"])
print(students["fatima"]["city"])
# Out:
# 0
# Lahore

# %%
for name, details in students.items():
    if "marks" in details and details["marks"] == 0:
        details["marks"] = 10
    print(name.capitalize(), "is", details["age"], "and scored", details["marks"])
# Out:
# Ali is 25 and scored 10
# Fatima is 23 and scored 92

# %% [markdown]
# > **Look at that shape and remember it.** A dictionary of dictionaries is exactly what comes back from a web API as JSON — which is Day 18, and which is what every AI API returns in Month 2. You are already reading it.

# %%
# A list of dictionaries - the other shape you will meet constantly
students = [
    {"name": "Ali", "marks": 85},
    {"name": "Fatima", "marks": 92},
    {"name": "Hassan", "marks": 78}
]

for s in students:
    print(s["name"], "scored", s["marks"])

print()
for s in students:
    if s["marks"] > 80:
        print(s["name"], "did well")
# Out:
# Ali scored 85
# Fatima scored 92
# Hassan scored 78
#
# Ali did well
# Fatima did well

# %% [markdown]
# ---
# # 6. Sets — a bag with no duplicates and no order
#
# A set uses curly braces like a dictionary, but holds single values, not pairs.
#
# Two rules define it:
#
# 1. **No duplicates.** Ever.
# 2. **No order.** There is no `set[0]`.

# %%
nums = {1, 2, 3, 2, 1, 4}

print(nums)              # the duplicates simply vanished
print(len(nums))
# Out:
# {1, 2, 3, 4}
# 4

# %%
# BREAKS ON PURPOSE - sets have no positions
nums = {1, 2, 3}
print(nums[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 # BREAKS ON PURPOSE - sets have no positions
#       2 nums = {1, 2, 3}
# ----> 3 print(nums[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### The thing sets are genuinely brilliant at

# %%
nums = [1, 2, 3, 2, 4, 1, 5, 3]

unique = set(nums)


print("original:", nums)
print("unique  :", unique)
# Out:
# original: [1, 2, 3, 2, 4, 1, 5, 3]
# unique  : {1, 2, 3, 4, 5}

# %% [markdown]
# Yesterday's duplicate-finding took a loop, a counter and an `if`. `set()` does it in one word.
#
# > **Careful:** the order is not guaranteed to be preserved. If order matters, use `sorted(set(nums))`.

# %%
# Membership checks are extremely fast in a set
names = {"ali", "fatima", "hassan"}

print("ali" in names)
print("zainab" in names)
# Out:
# True
# False

# %% [markdown]
# ### Set operations
#
# These are the ones the outline names, and they are genuinely useful.

# %%
python_students = {"ali", "fatima", "hassan", "ayesha"}
ai_students     = {"fatima", "hassan", "zainab"}

print("Both courses   :", python_students & ai_students)      # intersection
print("Either course  :", python_students | ai_students)      # union
print("Python only    :", python_students - ai_students)      # difference
print("Only one course:", python_students ^ ai_students)      # symmetric difference
# Out:
# Both courses   : {'hassan', 'fatima'}
# Either course  : {'ali', 'zainab', 'ayesha', 'hassan', 'fatima'}
# Python only    : {'ayesha', 'ali'}
# Only one course: {'zainab', 'ayesha', 'ali'}

# %%
# The word versions do the same thing and read better in real code
print(python_students.intersection(ai_students))
print(python_students.union(ai_students))
print(python_students.difference(ai_students))
print(python_students.symmetric_difference(ai_students))
# Out:
# {'hassan', 'fatima'}
# {'ali', 'zainab', 'ayesha', 'hassan', 'fatima'}
# {'ayesha', 'ali'}
# {'zainab', 'ayesha', 'ali'}

# %% [markdown]
# ### An empty set has a catch

# %%
empty = {}
print(type(empty))          # dict!  Not a set.

really_empty = set()
print(type(really_empty))   # this is how you make an empty set
# Out:
# <class 'dict'>
# <class 'set'>

# %% [markdown]
# ---
# # 7. Choosing between the four
#
# You now know all four of Python's core containers. This table is the whole week in one place.
#
# | | Written as | Ordered | Changeable | Duplicates | Look up by |
# |---|---|---|---|---|---|
# | **list** | `[1, 2, 3]` | yes | yes | yes | position |
# | **tuple** | `(1, 2, 3)` | yes | **no** | yes | position |
# | **dict** | `{"a": 1}` | yes | yes | keys: no | **key** |
# | **set** | `{1, 2, 3}` | **no** | yes | **no** | nothing — only `in` |
#
# **How to choose, in one sentence each:**
#
# - Things in order that will change → **list**
# - A fixed record that must not change → **tuple**
# - Things you look up by name → **dict**
# - A unique collection, or fast "is it in there?" → **set**

# %% [markdown]
# ---
# # 8. Looping over tuples, sets, and dictionaries — and their edge cases
#
# You've already looped over lists and dictionaries. Two things are worth knowing before you rely on this in real code: how looping over a tuple or a set behaves, and what happens if you try to change a collection *while* you're looping over it.
#
# ### Looping over a tuple

# %%
scores = (85, 92, 78)

for score in scores:
    print(score)

# %% [markdown]
# Reading a tuple in a loop is unremarkable — it behaves exactly like a list. The edge case is trying to change one *while* you're looping over it.

# %%
# BREAKS ON PURPOSE - a tuple cannot be changed, even one item at a time
scores = (85, 92, 78)
for i, score in enumerate(scores):
    scores[i] = score + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 4
#       2 scores = (85, 92, 78)
#       3 for i, score in enumerate(scores):
# ----> 4     scores[i] = score + 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **TypeError** — tuples are immutable, loop or no loop, so there is no way to write a new value back into one. If the values need to change, build a new tuple instead:

# %%
scores = (85, 92, 78)

boosted = []
for score in scores:
    boosted.append(score + 5)
boosted = tuple(boosted)      # a new tuple, not an edit

print(boosted)
# Out:
# (90, 97, 83)

# %% [markdown]
# ### Looping over a set

# %%
cities = {"Karachi", "Lahore", "Islamabad", "GK"}

for city in cities:
    print(city)
# Out:
# Lahore
# Karachi
# Islamabad
# GK

# %% [markdown]
# **Edge case 1: no guaranteed order.** Run that cell a few times — the order can vary. If order matters, sort it first:

# %%
for city in sorted(cities):
    print(city)
# Out:
# GK
# Islamabad
# Karachi
# Lahore

# %% [markdown]
# **Edge case 2: changing a set's size while looping over it.**

# %%
# BREAKS ON PURPOSE - changing a set's size while looping over it
numbers = {1, 2, 3, 4, 5}

# numbers.add(23)
# numbers.add(4)

print(numbers)

for n in numbers:
    if n % 2 == 0:
        numbers.remove(n)
# Out:
# {1, 2, 3, 4, 5}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 9
#       4 # numbers.add(23)
#       5 # numbers.add(4)
#       7 print(numbers)
# ----> 9 for n in numbers:
#      10     if n % 2 == 0:
#      11         numbers.remove(n)
#
# RuntimeError: Set changed size during iteration

# %% [markdown]
# **RuntimeError: Set changed size during iteration.** You're shrinking the set at the same time Python is walking through it, and it refuses to guess what should happen next. Loop over a copy, and edit the original:

# %%
numbers = {1, 2, 3, 4, 5}

for n in numbers.copy():        # loop over the copy, edit the original
    if n % 2 == 0:
        numbers.remove(n)

print(numbers)
# Out:
# {1, 3, 5}

# %% [markdown]
# ### Looping over a dictionary — the same edge case
#
# Section 4 already covered reading a dictionary in a loop. Changing its keys while you loop over it hits the exact same problem as a set.

# %%
# BREAKS ON PURPOSE - changing a dictionary's keys while looping over it
prices = {"apple": 100, "banana": 60, "mango": 250}
for item in prices.copy():
    if prices[item] > 80:
        del prices[item]

# %% [markdown]
# **RuntimeError: dictionary changed size during iteration.** Same fix as the set: loop over a snapshot of the keys, not the live dictionary.

# %%
prices = {"apple": 100, "banana": 60, "mango": 250}

print(prices.keys())
print(list(prices.keys()))

for item in list(prices.keys()):    # a snapshot, safe to loop while editing
    if prices[item] > 80:
        del prices[item]

print(prices)
# Out:
# dict_keys(['apple', 'banana', 'mango'])
# ['apple', 'banana', 'mango']
# {'banana': 60}

# %% [markdown]
# > **Lists are the odd one out.** Removing items from a list while looping over it doesn't raise an error — it silently skips items instead, which is worse, because nothing tells you it happened. Loop over `my_list.copy()` there too, for the same reason.

# %% [markdown]
# ---
# # 9. The classic: a word frequency counter
#
# This is the problem that makes dictionaries click. It also comes up in interviews constantly.

# %%
text = "the cat sat on the mat the cat was happy"

words = text.split()      # split() breaks text into a list at the spaces
print(words)
# Out:
# ['the', 'cat', 'sat', 'on', 'the', 'mat', 'the', 'cat', 'was', 'happy']

# %%
txt = "apple#banana#cherry#orange"

x = txt.split("#", 1)

print(x)
# Out:
# ['apple', 'banana#cherry#orange']

# %%
# Explaining the word count example

counts = {}

for word in words:
    # print("word:", word, "counts so far:", counts)
    if word in counts:
        counts[word] += 1      # seen before - add one
    else:
        counts[word] = 1       # first time - start at one

print(counts)
# Out:
# {'the': 3, 'cat': 2, 'sat': 1, 'on': 1, 'mat': 1, 'was': 1, 'happy': 1}

# %% [markdown]
# Read those five lines again slowly. That `if in / else` shape is the heart of it.
#
# `.get()` makes it shorter, and this is the version you will see in real code:

# %%
# Explain:
# if you use the get() method, you can simplify the code to 
# just one line inside the loop. 
# The get() method returns the value for the specified key 
# if the key is in the dictionary. If not,
# it returns a default value (which you can specify). 
# In this case, we use 0 as the default value, 
# so if the word hasn't been seen before, it will return 0, 
# and we add 1 to it.

counts = {}

for word in words:
    counts[word] = counts.get(word, 0) + 1

print(counts)
# Out:
# {'the': 3, 'cat': 2, 'sat': 1, 'on': 1, 'mat': 1, 'was': 1, 'happy': 1}

# %% [markdown]
# **"Give me the current count, or 0 if you've never seen this word, then add one."** One line, same result.

# %%
# Which word appeared most?
counts = {}
for word in words:
    counts[word] = counts.get(word, 0) + 1

most = max(counts, key=counts.get)
print(most, "appeared", counts[most], "times")

# Sorted from most to least
for word, n in sorted(counts.items(), key=lambda pair: pair[1], reverse=True):
    print(word, n)


# Lambda functions are small anonymous functions defined with the lambda keyword. 
# They can take any number of arguments but can only have one expression. 
# Lambda functions are often used for short, 
# throwaway functions that are not reused elsewhere in the code.

# x = lambda a : a + 10
# print(x(5))

# x = lambda a, b : a * b
# print(x(5, 6))
# Out:
# the appeared 3 times
# the 3
# cat 2
# sat 1
# on 1
# mat 1
# was 1
# happy 1
# 15
# 30

# %% [markdown]
# > Don't worry about `key=lambda ...` yet — that's Day 8. Just note that it exists and that sorting a dictionary by its values is a normal thing to want.

# %% [markdown]
# ---
# # 10. Weekly Skill Checkpoint
#
# > ### "I can confidently manipulate all of Python's core data structures"
#
# Work through these on your own. Ask for help when you're stuck — but try first.

# %% [markdown]
# ### Part A — dictionaries
#
# **A1.** Make a dictionary for yourself with name, age, city and favourite food. Print each on its own line using `.items()`.
#
# **A2.** Add a `hobbies` key holding a **list** of three hobbies. Then print the second hobby.
#
# **A3.** Given `prices = {"apple": 100, "banana": 60, "mango": 250}`, print every item costing more than 80.
#
# **A4.** Using the same dictionary, print the total cost of everything.
#
# **A5.** Ask the user for a fruit name and print its price — without crashing if the fruit isn't there.

# %% [markdown]
# ### Part B — sets
#
# **B1.** Remove the duplicates from `[3, 1, 4, 1, 5, 9, 2, 6, 5, 3]` and print the result **sorted**.
#
# **B2.** Given two lists of student names, print who is in both, who is only in the first, and everyone across the two.
#
# **B3.** Count how many **distinct** letters are in the word `"mississippi"`.

# %% [markdown]
# ### Part C — everything from this week
#
# **C1.** Ask for 5 numbers and print the largest, smallest and average. *(Days 3 and 4)*
#
# **C2.** Count the vowels in a word the user types. *(Days 2 and 3)*
#
# **C3.** Build a word frequency counter for a sentence the user types, and print the most common word.
#
# **C4.** Given a list of student dictionaries, print only those who passed (50 or above), sorted by marks:
# ```python
# students = [
#     {"name": "Ali", "marks": 85},
#     {"name": "Fatima", "marks": 42},
#     {"name": "Hassan", "marks": 67},
#     {"name": "Ayesha", "marks": 91}
# ]
# ```
#
# **C5.** Fix all three bugs in this code:
# ```python
# marks = [85, 42, 67]
# total = 0
# for m in marks:
#     total = 0
#     total += m
# average = total / len(marks)
# if average >= 50:
#     print("Class passed")
# elif average >= 80:
#     print("Excellent class")
# ```

# %%
# Your checkpoint space

# %% [markdown]
# ### Checkpoint solutions
#
# Try the exercises yourself first — these are one way to solve them.

# %%
# A1. Your own dictionary
me = {"name": "Owais", "age": 25, "city": "Karachi", "favourite_food": "biryani"}
for key, value in me.items():
    print(key, "->", value)

# A2. Add hobbies
me["hobbies"] = ["reading", "cricket", "coding"]
print(me["hobbies"][1])

# A3 and A4. Prices
prices = {"apple": 100, "banana": 60, "mango": 250}
for item, price in prices.items():
    if price > 80:
        print(item, price)
print("Total:", sum(prices.values()))

# A5. Safe lookup
fruit = input("Enter a fruit: ")
print(prices.get(fruit, "Not sold here"))

# %%
# B1. Dedupe and sort
nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
print(sorted(set(nums)))

# B2. Compare two groups
group_a = {"ali", "fatima", "hassan"}
group_b = {"fatima", "zainab", "hassan"}
print("Both:", group_a & group_b)
print("Only first:", group_a - group_b)
print("Everyone:", group_a | group_b)

# B3. Distinct letters
print(len(set("mississippi")))

# %%
# C1. Five numbers
numbers = []
for i in range(5):
    numbers.append(float(input("Enter a number: ")))
print("Largest:", max(numbers))
print("Smallest:", min(numbers))
print("Average:", sum(numbers) / len(numbers))

# C2. Count vowels
word = input("Enter a word: ")
vowels = 0
for letter in word:
    if letter.lower() in "aeiou":
        vowels += 1
print("Vowels:", vowels)

# C3. Word frequency counter
sentence = input("Enter a sentence: ")
counts = {}
for word in sentence.split():
    counts[word] = counts.get(word, 0) + 1
most_common = max(counts, key=counts.get)
print(counts)
print("Most common:", most_common)

# C4. Passing students, sorted by marks
students = [
    {"name": "Ali", "marks": 85},
    {"name": "Fatima", "marks": 42},
    {"name": "Hassan", "marks": 67},
    {"name": "Ayesha", "marks": 91}
]
passed = []
for s in students:
    if s["marks"] >= 50:
        passed.append(s)

passed.sort(key=lambda s: s["marks"])   # sort by the 'marks' key - lambda covered on Day 8
for s in passed:
    print(s["name"], s["marks"])

# C5. Fix the bugs: total was reset inside the loop (Day 3 accumulator
# bug), and the elif order meant ">= 80" could never be reached (Day 2)
marks = [85, 42, 67]
total = 0
for m in marks:
    total += m
average = total / len(marks)
if average >= 80:
    print("Excellent class")
elif average >= 50:
    print("Class passed")

# %% [markdown]
# ---
# ### This week you learned
#
# **Day 1** — binary, compilers, the PVM, variables, types, operators, `input()`
# **Day 2** — `if` / `elif` / `else`, `and` / `or` / `not`, truthiness, reading a traceback
# **Day 3** — `for`, `while`, `range()`, `break` / `continue` / `pass`, FizzBuzz
# **Day 4** — lists, indexing from 0, slicing, mutability, tuples, unpacking
# **Day 5** — dictionaries, `.get()`, `.items()`, sets, set operations
#
# That is enough to write real programs. Everything from here builds on these five days.
#
# **Next week:** functions — packaging your code so you write it once and use it forever.
